# %% [markdown]
# Vamos a realizar un análisis exploratorio de datos, primero realizamos una ingesta de los datos desde las diversas fuentes, para posteriormente aplicar las transformaciones pertinentes.

# %%
#importamos librerias necesarias

import pandas as pd
import numpy as np
import io
import requests

# %%
#Obtenemos los datasets con la libreria requests y pandas.
#Dataset amazon prime titles

url_amzn = 'https://raw.githubusercontent.com/HX-FAshur/PI01_DATA05/main/Datasets/amazon_prime_titles.csv'
bajada_datos_amzn = requests. get(url_amzn). content
amzn_df = pd. read_csv(io. StringIO(bajada_datos_amzn. decode('utf-8')))

#Dataset disney plus titles

url_disney = 'https://raw.githubusercontent.com/HX-FAshur/PI01_DATA05/main/Datasets/disney_plus_titles.csv'
bajada_datos_disney = requests. get(url_disney). content
disney_df = pd. read_csv(io. StringIO(bajada_datos_disney. decode('utf-8')))


#Dataset hulu titles

url_hulu = 'https://raw.githubusercontent.com/HX-FAshur/PI01_DATA05/main/Datasets/hulu_titles.csv'
bajada_datos_hulu = requests. get(url_hulu). content
hulu_df = pd. read_csv(io. StringIO(bajada_datos_hulu. decode('utf-8')))


#Dataset netflix titles

url_netflix = 'https://raw.githubusercontent.com/HX-FAshur/PI01_DATA05/main/Datasets/netflix_titles.json'
bajada_datos_netflix = requests. get(url_netflix). content
netflix_df = pd. read_json(io. StringIO(bajada_datos_netflix. decode('utf-8')))

# %%
#exploramos los datasets

# %%
amzn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7586 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %%
disney_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1450 non-null   object
#  1   type          1450 non-null   object
#  2   title         1450 non-null   object
#  3   director      977 non-null    object
#  4   cast          1260 non-null   object
#  5   country       1231 non-null   object
#  6   date_added    1447 non-null   object
#  7   release_year  1450 non-null   int64
#  8   rating        1447 non-null   object
#  9   duration      1450 non-null   object
#  10  listed_in     1450 non-null   object
#  11  description   1450 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 136.1+ KB

# %%
hulu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3073 non-null   object
#  1   type          3073 non-null   object
#  2   title         3073 non-null   object
#  3   director      3 non-null      object
#  4   cast          0 non-null      float64
#  5   country       1620 non-null   object
#  6   date_added    3045 non-null   object
#  7   release_year  3073 non-null   int64
#  8   rating        2553 non-null   object
#  9   duration      2594 non-null   object
#  10  listed_in     3073 non-null   object
#  11  description   3069 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 288.2+ KB

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %%
amzn_df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %% [markdown]
# Añadimos un nueva columna llamada "plataforma" la cual tendrá el nombre de su la respectiva plataforma del dataset.

# %%
amzn_df['plataforma']='amazon'
disney_df['plataforma']='disney'
hulu_df['plataforma']='hulu'
netflix_df['plataforma']='netflix'

# %% [markdown]
# En la columna 'show_id' añadimos el prefijo de la plataforma para diferenciarlos más adelante.

# %%
amzn_df['show_id']='amzn'+ amzn_df['show_id']
disney_df['show_id']='dis'+ disney_df['show_id']
hulu_df['show_id']='hu'+ hulu_df['show_id']
netflix_df['show_id']='net'+ netflix_df['show_id']

# %%
amzn_df.head()
# Out:
#   show_id   type                 title        director  \
# 0  amzns1  Movie   The Grand Seduction    Don McKellar
# 1  amzns2  Movie  Take Care Good Night    Girish Joshi
# 2  amzns3  Movie  Secrets of Deception     Josh Webber
# 3  amzns4  Movie    Pink: Staying True  Sonia Anderson
# 4  amzns5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
# Normalizacion de columnas
amzn_df.columns = ['Pelicula_id','Tipo', 'Titulo', 'Director', 'Elenco', 'Pais', 'Fecha_añadida', 'Año_lanzamiento', 'Clasificacion', 'Duracion', 'Listada_en', 'Descripcion','Plataforma']
disney_df.columns = ['Pelicula_id','Tipo', 'Titulo', 'Director', 'Elenco', 'Pais', 'Fecha_añadida', 'Año_lanzamiento', 'Clasificacion', 'Duracion', 'Listada_en', 'Descripcion','Plataforma']
hulu_df.columns = ['Pelicula_id','Tipo', 'Titulo', 'Director', 'Elenco', 'Pais', 'Fecha_añadida', 'Año_lanzamiento', 'Clasificacion', 'Duracion', 'Listada_en', 'Descripcion','Plataforma']
netflix_df.columns = ['Pelicula_id','Tipo', 'Titulo', 'Director', 'Elenco', 'Pais', 'Fecha_añadida', 'Año_lanzamiento', 'Clasificacion', 'Duracion', 'Listada_en', 'Descripcion','Plataforma']

# %% [markdown]
# borramos los espacios a los costados de la columna 'Fecha_añadida' y le cambiamos el tipo a datetime

# %%
amzn_df['Fecha_añadida']=amzn_df['Fecha_añadida'].str.lstrip()
amzn_df['Fecha_añadida']=amzn_df['Fecha_añadida'].str.rstrip()
amzn_df['Fecha_añadida']=pd.to_datetime(amzn_df['Fecha_añadida'], format= '%B %d, %Y')

disney_df['Fecha_añadida']=disney_df['Fecha_añadida'].str.lstrip()
disney_df['Fecha_añadida']=disney_df['Fecha_añadida'].str.rstrip()
disney_df['Fecha_añadida']=pd.to_datetime(disney_df['Fecha_añadida'], format= '%B %d, %Y')

hulu_df['Fecha_añadida']=hulu_df['Fecha_añadida'].str.lstrip()
hulu_df['Fecha_añadida']=hulu_df['Fecha_añadida'].str.rstrip()
hulu_df['Fecha_añadida']=pd.to_datetime(hulu_df['Fecha_añadida'], format= '%B %d, %Y')

netflix_df['Fecha_añadida']=netflix_df['Fecha_añadida'].str.lstrip()
netflix_df['Fecha_añadida']=netflix_df['Fecha_añadida'].str.rstrip()
netflix_df['Fecha_añadida']=pd.to_datetime(netflix_df['Fecha_añadida'], format= '%B %d, %Y')

# %% [markdown]
# En la columna duración también se eliminan los espacios laterales

# %%
amzn_df['Duracion']=amzn_df['Duracion'].str.lstrip()
amzn_df['Duracion']=amzn_df['Duracion'].str.rstrip()

disney_df['Duracion']=disney_df['Duracion'].str.lstrip()
disney_df['Duracion']=disney_df['Duracion'].str.rstrip()

hulu_df['Duracion']=hulu_df['Duracion'].str.lstrip()
hulu_df['Duracion']=hulu_df['Duracion'].str.rstrip()

netflix_df['Duracion']=netflix_df['Duracion'].str.lstrip()
netflix_df['Duracion']=netflix_df['Duracion'].str.rstrip()

# %% [markdown]
# Ahora separamos la columna 'duracion' por min

# %%
sep_amzn=amzn_df['Duracion'].str.split(" ", n = 1, expand = True) 
sep_hulu=hulu_df['Duracion'].str.split(" ", n = 1, expand = True)
sep_disney=disney_df['Duracion'].str.split(" ", n = 1, expand = True)
sep_netflix=netflix_df['Duracion'].str.split(" ", n = 1, expand = True)

# %%
amzn_df['duracion_int']=sep_amzn[0]
amzn_df['duracion_tipo']=sep_amzn[1]

disney_df['duracion_int']=sep_disney[0]
disney_df['duracion_tipo']=sep_disney[1]

hulu_df['duracion_int']=sep_hulu[0]
hulu_df['duracion_tipo']=sep_hulu[1]

netflix_df['duracion_int']=sep_netflix[0]
netflix_df['duracion_tipo']=sep_netflix[1]

# %%
amzn_df
# Out:
#      Pelicula_id     Tipo                   Titulo         Director  \
# 0         amzns1    Movie      The Grand Seduction     Don McKellar
# 1         amzns2    Movie     Take Care Good Night     Girish Joshi
# 2         amzns3    Movie     Secrets of Deception      Josh Webber
# 3         amzns4    Movie       Pink: Staying True   Sonia Anderson
# 4         amzns5    Movie            Monster Maker     Giles Foster
# ...          ...      ...                      ...              ...
# 9663   amzns9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   amzns9665  TV Show            Planet Patrol              NaN
# 9665   amzns9666    Movie                  Outpost     Steve Barker
# 9666   amzns9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   amzns9668    Movie              Harry Brown    Daniel Barber
#
#                                                  Elenco            Pais  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %% [markdown]
# Ahora concatenamos los 4 datasets.

# %%
concat_1 = pd.concat([amzn_df, disney_df], axis=0)
concat_2=pd.concat([hulu_df,netflix_df], axis=0)
movies_df=pd.concat([concat_1,concat_2], axis=0)

# %%
movies_df
# Out:
#      Pelicula_id     Tipo                Titulo         Director  \
# 0         amzns1    Movie   The Grand Seduction     Don McKellar
# 1         amzns2    Movie  Take Care Good Night     Girish Joshi
# 2         amzns3    Movie  Secrets of Deception      Josh Webber
# 3         amzns4    Movie    Pink: Staying True   Sonia Anderson
# 4         amzns5    Movie         Monster Maker     Giles Foster
# ...          ...      ...                   ...              ...
# 8802    nets8803    Movie                Zodiac    David Fincher
# 8803    nets8804  TV Show           Zombie Dumb             None
# 8804    nets8805    Movie            Zombieland  Ruben Fleischer
# 8805    nets8806    Movie                  Zoom     Peter Hewitt
# 8806    nets8807    Movie                Zubaan      Mozez Singh
#
#                                                  Elenco            Pais  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %% [markdown]
# normalizamos la letra del dataset final.

# %%
amzn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Pelicula_id      9668 non-null   object
#  1   Tipo             9668 non-null   object
#  2   Titulo           9668 non-null   object
#  3   Director         7586 non-null   object
#  4   Elenco           8435 non-null   object
#  5   Pais             672 non-null    object
#  6   Fecha_añadida    155 non-null    datetime64[ns]
#  7   Año_lanzamiento  9668 non-null   int64
#  8   Clasificacion    9331 non-null   object
#  9   Duracion         9668 non-null   object
#  10  Listada_en       9668 non-null   object
#  11  Descripcion      9668 non-null   object
#  12  Plataforma       9668 non-null   object
#  13  duracion_int     9668 non-null   object
#  14  duracion_tipo    9668 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(13)
# memory usage: 1.1+ MB

# %%
movies_df['Pelicula_id']=movies_df['Pelicula_id'].str.lower()
movies_df['Tipo']=movies_df['Tipo'].str.lower()
movies_df['Titulo']=movies_df['Titulo'].str.lower()
movies_df['Director']=movies_df['Director'].str.lower()
movies_df['Elenco']=movies_df['Elenco'].str.lower()
movies_df['Pais']=movies_df['Pais'].str.lower()
movies_df['Clasificacion']=movies_df['Clasificacion'].str.lower()
movies_df['Duracion']=movies_df['Duracion'].str.lower()
movies_df['Listada_en']=movies_df['Listada_en'].str.lower()
movies_df['Descripcion']=movies_df['Descripcion'].str.lower()
movies_df['Plataforma']=movies_df['Plataforma'].str.lower()
movies_df['duracion_tipo']=movies_df['duracion_tipo'].str.lower()

# %%
movies_df['duracion_tipo'].unique()
# Out:
# array(['min', 'season', 'seasons', nan, None], dtype=object)

# %% [markdown]
# Reemplazamos la palabra 'seasons' por 'season'

# %%
movies_df['duracion_tipo'].replace({'seasons':'season'}, inplace=True)

# %%
movies_df['duracion_tipo'].unique()
# Out:
# array(['min', 'season', nan, None], dtype=object)

# %% [markdown]
# Finalmente exportamos el archivo en formato csv, el cual nos serivirá para hacer las consultas en nuesta API.

# %%
movies_df.to_csv('movies.csv', encoding='utf-8', index=False)
